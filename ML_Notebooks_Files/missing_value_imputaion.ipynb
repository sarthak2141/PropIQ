# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
pd.set_option('display.max_columns',None)

# %%
df=pd.read_csv('gurgaon_properties_outlier_treated.csv')

# %%
df.head()
# Out:
#   property_type               society     sector  price  price_per_sqft  \
# 0          flat            gls avenue  sector 92   0.21          6954.0
# 1          flat        paras quartier  sector 59   5.90         11028.0
# 2          flat  hsiidc sidco aravali   sector 1   0.90          3477.0
# 3         house  sector 15 part 2 rwa  sector 15  10.00         22120.0
# 4          flat       eldeco accolade  sector 48   0.72          4975.0
#
#       area                                       areaWithType  bedRoom  \
# 0   302.00                     Carpet area: 302 (28.06 sq.m.)      1.0
# 1  5350.00                 Built Up area: 5350 (497.03 sq.m.)      4.0
# 2  2588.40  Super Built up area 2588(240.43 sq.m.)Built Up...      3.0
# 3  4520.84                        Plot area 502(419.74 sq.m.)      5.0
# 4  1447.20  Super Built up area 1457(135.36 sq.m.)Carpet a...      2.0
#
#    bathroom balcony  floorNum      facing   agePossession  \
# ...

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                   1
# sector                    0
# price                     0
# price_per_sqft            0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                  2
# facing                 1049
# agePossession             0
# super_built_up_area    1758
# built_up_area          1988
# carpet_area            1769
# study room                0
# servent room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxury_score              0
# area_room_ratio           0
# dtype: int64

# %% [markdown]
# # Built up Area

# %%
df[df['super_built_up_area'].isnull()]
# Out:
#      property_type                                       society      sector  \
# 0             flat                                    gls avenue   sector 92
# 1             flat                                paras quartier   sector 59
# 3            house                          sector 15 part 2 rwa   sector 15
# 5             flat                          dlf belvedere towers   sector 25
# 6             flat                      pareena coban residences   sector 99
# ...            ...                                           ...         ...
# 3629          flat                                    ardee city   sector 52
# 3630          flat                        conscient heritage max  sector 102
# 3632          flat                         alpha corp gurgaonone   sector 84
# 3633          flat  central park flower valley aqua front towers   sector 33
# 3634          flat                                dlf the arbour   sector 63
#
#       price  price_per_sqft     area  \
# ...

# %%
sns.scatterplot(x=df['built_up_area'],y=df['super_built_up_area'])
# Out:
# <Axes: xlabel='built_up_area', ylabel='super_built_up_area'>

# %%
sns.scatterplot(x=df['carpet_area'],y=df['super_built_up_area'])
# Out:
# <Axes: xlabel='carpet_area', ylabel='super_built_up_area'>

# %%
df[df['built_up_area'].isnull()]
# Out:
#      property_type                      society     sector  price  \
# 0             flat                   gls avenue  sector 92   0.21
# 4             flat              eldeco accolade  sector 48   0.72
# 5             flat         dlf belvedere towers  sector 25   3.40
# 7             flat       vatika the seven lamps  sector 82   1.39
# 9             flat                            .  sector 59   7.00
# ...            ...                          ...        ...    ...
# 3635          flat        signature global park  sector 36   0.72
# 3636          flat  bestech park view grand spa  sector 81   2.35
# 3637          flat                   mm heights  sector 65   2.10
# 3638          flat               vipul belmonte  sector 53   6.00
# 3639          flat              corona gracieux  sector 76   1.05
#
#       price_per_sqft    area  \
# 0             6954.0   302.0
# 4             4975.0  1447.2
# 5            13765.0  2470.0
# 7             6412.0  2167.8
# ...

# %%
df[df['carpet_area'].isnull()]
# Out:
#      property_type                   society     sector  price  \
# 1             flat            paras quartier  sector 59   5.90
# 2             flat      hsiidc sidco aravali   sector 1   0.90
# 3            house      sector 15 part 2 rwa  sector 15  10.00
# 6             flat  pareena coban residences  sector 99   1.30
# 7             flat    vatika the seven lamps  sector 82   1.39
# ...            ...                       ...        ...    ...
# 3627          flat   aipl the peaceful homes  sector 70   2.52
# 3628          flat        ambience creacions  sector 22   3.20
# 3635          flat     signature global park  sector 36   0.72
# 3638          flat            vipul belmonte  sector 53   6.00
# 3639          flat           corona gracieux  sector 76   1.05
#
#       price_per_sqft     area  \
# 1            11028.0  5350.00
# 2             3477.0  2588.40
# 3            22120.0  4520.84
# 6             6510.0  1996.90
# 7             6412.0  2167.80
# ...

# %%
df[(df['super_built_up_area'].isnull())&(df['built_up_area'].isnull())&(df['carpet_area'].isnull())]
# Out:
# Empty DataFrame
# Columns: [property_type, society, sector, price, price_per_sqft, area, areaWithType, bedRoom, bathroom, balcony, floorNum, facing, agePossession, super_built_up_area, built_up_area, carpet_area, study room, servent room, store room, pooja room, others, furnishing_type, luxury_score, area_room_ratio]
# Index: []

# %%
df[(df['super_built_up_area'].isnull())|(df['built_up_area'].isnull())|(df['carpet_area'].isnull())]
# Out:
#      property_type                      society     sector  price  \
# 0             flat                   gls avenue  sector 92   0.21
# 1             flat               paras quartier  sector 59   5.90
# 2             flat         hsiidc sidco aravali   sector 1   0.90
# 3            house         sector 15 part 2 rwa  sector 15  10.00
# 4             flat              eldeco accolade  sector 48   0.72
# ...            ...                          ...        ...    ...
# 3635          flat        signature global park  sector 36   0.72
# 3636          flat  bestech park view grand spa  sector 81   2.35
# 3637          flat                   mm heights  sector 65   2.10
# 3638          flat               vipul belmonte  sector 53   6.00
# 3639          flat              corona gracieux  sector 76   1.05
#
#       price_per_sqft     area  \
# 0             6954.0   302.00
# 1            11028.0  5350.00
# 2             3477.0  2588.40
# 3            22120.0  4520.84
# ...

# %%
allpresent_df=df[~((df['super_built_up_area'].isnull())|(df['built_up_area'].isnull())|(df['carpet_area'].isnull()))]

# %%
allpresent_df.shape
# Out:
# (533, 24)

# %%
allpresent_df.head()
# Out:
#    property_type              society      sector  price  price_per_sqft  \
# 12          flat  experion windchants  sector 112   2.80         11470.0
# 17          flat          ss the leaf   sector 85   1.93          8075.0
# 37          flat      sagar apartment   sector 56   1.45          7250.0
# 53          flat        tata primanti   sector 72   3.21         15000.0
# 54          flat   ramprastha primera   sector 37   1.10          6111.0
#
#       area                                       areaWithType  bedRoom  \
# 12  2441.2  Super Built up area 2441(226.78 sq.m.)Built Up...      2.0
# 17  2390.1  Super Built up area 2408(223.71 sq.m.)Built Up...      3.0
# 37  2000.0  Super Built up area 2000(185.81 sq.m.)Built Up...      3.0
# 53  2140.0  Super Built up area 2185(202.99 sq.m.)Built Up...      3.0
# 54  1800.0  Super Built up area 1800(167.23 sq.m.)Built Up...      3.0
#
#     bathroom balcony  floorNum      facing   agePossession  \
# ...

# %%
super_to_built_up_ratio=allpresent_df['super_built_up_area']/allpresent_df['built_up_area']
carpet_to_built_up_ratio=allpresent_df['carpet_area']/allpresent_df['built_up_area']

# %%
super_to_built_up_ratio,carpet_to_built_up_ratio
# Out:
# (12      1.258877
#  17      1.003333
#  37      1.052632
#  53      1.021028
#  54      1.058824
#            ...
#  3613    1.176569
#  3614    1.455939
#  3617    1.115108
#  3626    1.080000
#  3640    1.013333
#  Length: 533, dtype: float64,
#  12      0.928299
#  17      0.995833
#  37      0.947368
#  53      0.934579
#  54      0.941176
#            ...
#  3613    0.823431
#  3614    0.898851
#  3617    0.892086
#  3626    0.782500
#  3640    0.842051
#  Length: 533, dtype: float64)

# %%
super_to_built_up_ratio=(allpresent_df['super_built_up_area']/allpresent_df['built_up_area']).median()
carpet_to_built_up_ratio=(allpresent_df['carpet_area']/allpresent_df['built_up_area']).median()

# %%
super_to_built_up_ratio,carpet_to_built_up_ratio
# Out:
# (1.105263157894737, 0.9)

# %%
sbc_df=df[~(df['super_built_up_area'].isnull())&(df['built_up_area'].isnull())&~(df['carpet_area'].isnull())]

# %%
sbc_df.head()
# Out:
#    property_type                   society     sector  price  price_per_sqft  \
# 4           flat           eldeco accolade  sector 48   0.72          4975.0
# 11          flat             pioneer araya  sector 62   9.14         19488.0
# 13          flat  emaar mgf emerald estate  sector 65   1.30         20602.0
# 18          flat         mapsko casa bella  sector 82   0.86          8120.0
# 22          flat            dlf the primus  sector 82   1.59         10338.0
#
#       area                                       areaWithType  bedRoom  \
# 4   1447.2  Super Built up area 1457(135.36 sq.m.)Carpet a...      2.0
# 11  4690.1  Super Built up area 4690(435.72 sq.m.)Carpet a...      4.0
# 13   631.0  Super Built up area 1020(94.76 sq.m.)Carpet ar...      2.0
# 18  1059.1  Super Built up area 1430(132.85 sq.m.)Carpet a...      3.0
# 22  1538.0  Super Built up area 1799(167.13 sq.m.)Carpet a...      3.0
#
#     bathroom balcony  floorNum      facing   agePossession  \
# ...

# %%
# here we take avg of  built up area that we calculate from super built up and built up  area by the help of ratio b/w them
sbc_df['built_up_area'].fillna(round(((sbc_df['super_built_up_area']/1.05) + (sbc_df['carpet_area']/0.9))/2),inplace=True)
# Out:
# C:\Users\sarth\AppData\Local\Temp\ipykernel_3080\280024762.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   sbc_df['built_up_area'].fillna(round(((sbc_df['super_built_up_area']/1.05) + (sbc_df['carpet_area']/0.9))/2),inplace=True)
# C:\Users\sarth\AppData\Local\Temp\ipykernel_3080\280024762.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
sb_df=df[~(df['super_built_up_area'].isnull())&(df['built_up_area'].isnull())&(df['carpet_area'].isnull())]

# %%
sb_df.head()
# Out:
#    property_type                  society     sector  price  price_per_sqft  \
# 7           flat   vatika the seven lamps  sector 82   1.39          6412.0
# 9           flat                        .  sector 59   7.00         11000.0
# 10          flat             tulip violet  sector 69   1.85          9203.0
# 16          flat           dlf the ultima  sector 81   3.45         12012.0
# 19          flat  shree vardhman victoria  sector 70   1.07          7925.0
#
#       area                            areaWithType  bedRoom  bathroom balcony  \
# 7   2167.8  Super Built up area 2160(200.67 sq.m.)      3.0         3      3+
# 9   6363.6  Super Built up area 6000(557.42 sq.m.)      4.0         4      3+
# 10  2010.2  Super Built up area 2010(186.74 sq.m.)      4.0         4       2
# 16  2872.1  Super Built up area 2872(266.82 sq.m.)      4.0         4      3+
# 19  1350.2  Super Built up area 1350(125.42 sq.m.)      2.0         2       3
#
# ...

# %%
sb_df.shape
# Out:
# (881, 24)

# %%
sb_df['built_up_area'].fillna(round(sb_df['super_built_up_area']/1.05),inplace=True)
# Out:
# C:\Users\sarth\AppData\Local\Temp\ipykernel_3080\756193786.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   sb_df['built_up_area'].fillna(round(sb_df['super_built_up_area']/1.05),inplace=True)
# C:\Users\sarth\AppData\Local\Temp\ipykernel_3080\756193786.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
c_df=df[(df['super_built_up_area'].isnull())&(df['built_up_area'].isnull())&~(df['carpet_area'].isnull())]

# %%
c_df.head()
# Out:
#    property_type                 society     sector  price  price_per_sqft  \
# 0           flat              gls avenue  sector 92   0.21          6954.0
# 5           flat    dlf belvedere towers  sector 25   3.40         13765.0
# 14          flat          dlf the primus  sector 82   3.50         13430.0
# 20          flat  bestech park view city  sector 48   1.80         10250.0
# 23          flat    siddhartha apartment  sector 95   1.10          4327.0
#
#       area                      areaWithType  bedRoom  bathroom balcony  \
# 0    302.0    Carpet area: 302 (28.06 sq.m.)      1.0         1       1
# 5   2470.0  Carpet area: 2470 (229.47 sq.m.)      4.0         4       3
# 14  2606.1  Carpet area: 2606 (242.11 sq.m.)      5.0         5      3+
# 20  1756.1  Carpet area: 1756 (163.14 sq.m.)      3.0         4       3
# 23  2542.2  Carpet area: 2542 (236.16 sq.m.)      4.0         3       3
#
#     floorNum      facing   agePossession  super_built_up_area  built_up_area  \
# ...

# %%
c_df.shape
# Out:
# (686, 24)

# %%
c_df['built_up_area'].fillna(round(sc_df['carpet_area']/0.9),inplace=True)
# Out:
# C:\Users\sarth\AppData\Local\Temp\ipykernel_3080\1617539910.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   c_df['built_up_area'].fillna(round(sc_df['carpet_area']/0.9),inplace=True)
# C:\Users\sarth\AppData\Local\Temp\ipykernel_3080\1617539910.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df.update(sbc_df)
df.update(sb_df)
df.update(c_df)

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                   1
# sector                    0
# price                     0
# price_per_sqft            0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                  2
# facing                 1049
# agePossession             0
# super_built_up_area    1758
# built_up_area             0
# carpet_area            1769
# study room                0
# servent room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxury_score              0
# area_room_ratio           0
# dtype: int64

# %%
sns.scatterplot(x=df['built_up_area'],y=df['price'])
# Out:
# <Axes: xlabel='built_up_area', ylabel='price'>

# %%
anomoly_df=df[(df['built_up_area']<2000)&(df['price']>2.5)][['price','area','built_up_area']]

# %%
anomoly_df.sample(10)
# Out:
#       price     area  built_up_area
# 2822   3.80  2164.00         1700.0
# 680    4.25  1840.63          200.0
# 1151   8.50  4520.84          500.0
# 1346  10.00  3875.04          483.0
# 2452   8.00  3099.96          347.0
# 2053  11.00  4047.23          360.0
# 2253   8.00  3132.29          387.0
# 227    3.60  1453.13         1449.0
# 2825   2.51  2093.10         1993.0
# 2676  12.50  4230.21          410.0

# %%
anomoly_df.shape
# Out:
# (258, 3)

# %%
anomoly_df=anomoly_df[~(anomoly_df['area']<anomoly_df['built_up_area'])]

# %%
anomoly_df['built_up_area']=anomoly_df['area']

# %%
df.update(anomoly_df)

# %%
sns.scatterplot(x=df['built_up_area'],y=df['price'])
# Out:
# <Axes: xlabel='built_up_area', ylabel='price'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3641 entries, 0 to 3640
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   property_type        3641 non-null   object
#  1   society              3640 non-null   object
#  2   sector               3641 non-null   object
#  3   price                3641 non-null   float64
#  4   price_per_sqft       3641 non-null   float64
#  5   area                 3641 non-null   float64
#  6   areaWithType         3641 non-null   object
#  7   bedRoom              3641 non-null   float64
#  8   bathroom             3641 non-null   int64
#  9   balcony              3641 non-null   object
#  10  floorNum             3639 non-null   float64
#  11  facing               2592 non-null   object
#  12  agePossession        3641 non-null   object
#  13  super_built_up_area  1883 non-null   float64
#  14  built_up_area        3641 non-null   float64
# ...

# %%
df.drop(columns=['area','areaWithType','super_built_up_area','carpet_area','area_room_ratio'],inplace=True)

# %%
df.head()
# Out:
#   property_type               society     sector  price  price_per_sqft  \
# 0          flat            gls avenue  sector 92   0.21          6954.0
# 1          flat        paras quartier  sector 59   5.90         11028.0
# 2          flat  hsiidc sidco aravali   sector 1   0.90          3477.0
# 3         house  sector 15 part 2 rwa  sector 15  10.00         22120.0
# 4          flat       eldeco accolade  sector 48   0.72          4975.0
#
#    bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 0      1.0         1       1       0.0  South-East  Relatively New
# 1      4.0         4      3+       0.0         NaN  Moderately old
# 2      3.0         3      3+       8.0        East  Moderately old
# 3      5.0         5       2       2.0        East    Old Property
# 4      2.0         2      3+      12.0        East  Relatively New
#
#    built_up_area  study room  servent room  store room  pooja room  others  \
# ...

# %%
df.isnull().sum()
# Out:
# property_type         0
# society               1
# sector                0
# price                 0
# price_per_sqft        0
# bedRoom               0
# bathroom              0
# balcony               0
# floorNum              2
# facing             1049
# agePossession         0
# built_up_area         0
# study room            0
# servent room          0
# store room            0
# pooja room            0
# others                0
# furnishing_type       0
# luxury_score          0
# dtype: int64

# %% [markdown]
# # floorNum

# %%
df[df['floorNum'].isnull()]
# Out:
#      property_type             society      sector  price  price_per_sqft  \
# 1776          flat                 NaN   sector 78   0.60          3692.0
# 3494          flat  experion heartsong  sector 106   1.08          6150.0
#
#       bedRoom  bathroom balcony  floorNum facing       agePossession  \
# 1776      2.0         2       0       NaN    NaN  Under Construction
# 3494      3.0         3       0       NaN    NaN  Under Construction
#
#       built_up_area  study room  servent room  store room  pooja room  others  \
# 1776         1625.0           0             0           0           0       0
# 3494         1758.0           0             0           0           0       0
#
#       furnishing_type  luxury_score
# 1776                0             0
# 3494                0             0

# %%
df=df[~df['floorNum'].isnull()]

# %% [markdown]
# # Facing

# %%
df['facing'].value_counts().plot(kind='pie',autopct="0.2f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df.drop(columns='facing',inplace=True)

# %%
df.sample(5)
# Out:
#      property_type                 society      sector  price  price_per_sqft  \
# 3225         house             independent    sector 4   0.67          8527.0
# 3616          flat         raheja vedaanta  sector 108   1.00          4854.0
# 2123          flat      supertech araville   sector 79   0.95          6209.0
# 473           flat    shree vardhman flora   sector 90   0.64          4923.0
# 2777          flat  vatika the seven lamps   sector 82   0.85          6538.0
#
#       bedRoom  bathroom balcony  floorNum   agePossession  built_up_area  \
# 3225      3.0         2       1       1.0  Moderately old          783.0
# 3616      2.0         2       2       0.0       Undefined         2060.0
# 2123      2.0         2       3       7.0    New Property         1457.0
# 473       2.0         2       3       6.0    Old Property         1230.0
# 2777      2.0         2       2       0.0  Relatively New         1238.0
#
# ...

# %%
df.isnull().sum()
# Out:
# property_type      0
# society            0
# sector             0
# price              0
# price_per_sqft     0
# bedRoom            0
# bathroom           0
# balcony            0
# floorNum           0
# agePossession      0
# built_up_area      0
# study room         0
# servent room       0
# store room         0
# pooja room         0
# others             0
# furnishing_type    0
# luxury_score       0
# dtype: int64

# %% [markdown]
# # agePossession

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1625
# Moderately old         565
# New Property           565
# Undefined              446
# Old Property           316
# Under Construction     122
# Name: count, dtype: int64

# %%
df[df['agePossession']=='Undefined']
# Out:
#      property_type                   society      sector  price  \
# 6             flat  pareena coban residences   sector 99   1.30
# 8             flat          global hill view   sector 11   0.33
# 50           house               independent   sector 48   0.82
# 57            flat       aipl zen residences   sector 70   1.25
# 61            flat    tashee capital gateway  sector 111   0.96
# ...            ...                       ...         ...    ...
# 3602          flat     signature global park   sector 48   0.87
# 3611          flat             ashiana anmol   sector 48   0.90
# 3616          flat           raheja vedaanta  sector 108   1.00
# 3620          flat     signature global park   sector 48   0.75
# 3634          flat            dlf the arbour   sector 63   7.90
#
#       price_per_sqft  bedRoom  bathroom balcony  floorNum agePossession  \
# 6             6510.0      3.0         3       0      16.0     Undefined
# ...

# %%
def mode_based_imputation(row):
    if row['agePossession']=='Undefined':
        mode_value= df[(df['property_type']==row['property_type'])&(df['sector']==row['sector'])]['agePossession'].mode()
        if not  mode_value.empty:
            return mode_value.iloc[0]
        else:
            return np.nan
    else:
        return row['agePossession']

# %%
df['agePossession']=df.apply(mode_based_imputation,axis=1)

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1809
# New Property           639
# Moderately old         613
# Old Property           353
# Under Construction     122
# Undefined              103
# Name: count, dtype: int64

# %%
def mode_based_imputation2(row):
    if row['agePossession']=='Undefined':
        mode_value= df[(df['sector']==row['sector'])]['agePossession'].mode()
        if not  mode_value.empty:
            return mode_value.iloc[0]
        else:
            return np.nan
    else:
        return row['agePossession']

# %%
df['agePossession']=df.apply(mode_based_imputation2,axis=1)

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1837
# New Property           665
# Moderately old         621
# Old Property           356
# Under Construction     122
# Undefined               38
# Name: count, dtype: int64

# %%
def mode_based_imputation3(row):
    if row['agePossession']=='Undefined':
        mode_value=df[(df['property_type']==row['property_type'])]['agePossession'].mode() 
        if not mode_value.empty:
            return mode_value.iloc[0]
        else:
            return np.nan
    else:
        return row['agePossession']

# %%
df['agePossession']=df.apply(mode_based_imputation3,axis=1)

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1853
# New Property           665
# Moderately old         643
# Old Property           356
# Under Construction     122
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# property_type      0
# society            0
# sector             0
# price              0
# price_per_sqft     0
# bedRoom            0
# bathroom           0
# balcony            0
# floorNum           0
# agePossession      0
# built_up_area      0
# study room         0
# servent room       0
# store room         0
# pooja room         0
# others             0
# furnishing_type    0
# luxury_score       0
# dtype: int64

# %%
df.to_csv('gurgaon_properties_missing_value_imputation.csv',index=False)

# %%
df.shape
# Out:
# (3639, 18)
